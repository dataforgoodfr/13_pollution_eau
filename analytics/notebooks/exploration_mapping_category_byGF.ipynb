# %% [markdown]
# # Notebook Objective
#
# ## Data Exploration and Cleaning
#
# Explore and clean reference data from GF to prepare it for use as a seed file.
#
# ### Source Data
#
# - **Source**: Google Spreadsheet
# - **Link**: [GF Reference Data](https://docs.google.com/spreadsheets/d/1W239EkEV72WzzefB6jbYUQkIIQ-9xa4u9_m8XdCpU4o/edit?gid=1263453670#gid=1263453670)
#
# ### Tasks
#
# 1. **Data Exploration**
#
#    - Analyze raw data structure
#    - Identify data types
#    - Check for missing values
#    - Review data consistency
#
# 2. **Data Cleaning**
#
#    - Handle missing values
#    - Correct data types
#    - Standardize formats
#
# 3. **Data Transformation**
#    - Create new CSV file
#    - Prepare for use as seed data
#
# ### Output
#
# - Clean, formatted CSV file ready for use as a seed file in the project
#
# This notebook will document the process of transforming raw reference data into a clean, structured format suitable for further use.

# %%
from pathlib import Path
import pandas as pd

# 13_pollution_eau_d4g/dbt_/seeds/mapping_categorie_new.csv
map_cat_file = Path.cwd().parent.parent / "dbt_/seeds/mapping_category_gf.csv"
df = pd.read_csv(map_cat_file)

df.head(2)
# Out:
#   cdparametresiseeaux  cdparametre             libmajparametre  \
# 0                PFOA       5347.0  ACIDE PERFLUORO-OCTANOÏQUE
# 1               PFHPA       5977.0  ACIDE PERFLUOROHEPTANOÏQUE
#
#               libminparametre  casparam categorie sous catégorie  \
# 0  Acide perfluoro-octanoïque  335-67-1      PFAS            NaN
# 1  Acide perfluoroheptanoïque  375-85-9      PFAS            NaN
#
#   Détails sous catégorie  Limite qualité  Unité limite qualité  \
# 0                    NaN              NaN                  NaN
# 1                    NaN              NaN                  NaN
#
#   Commentaire limite qualité Valeur sanitaire 1 Unité valeur sanitaire 1  \
# 0                        NaN              0.075                     µg/L
# 1                        NaN              0.075                     µg/L
#
#                       Commentaire valeur sanitaire 1  Valeur sanitaire 2  \
# 0  Valeur sanitaire indicative établie par l'Anse...                 NaN
# 1  Valeur sanitaire indicative établie par l'Anse...                 NaN
#
#   Unité valeur sanitaire 2 Commentaire valeur sanitaire 2
# 0                      NaN                            NaN
# 1                      NaN                            NaN

# %%
# base information + check null value coverage
# cdparametre has null value,but the above sql has pre-filled the empty cdparametre columne with 0
# conclution: the libmajparametre,libminparametre,categorie has no null value,
info = pd.DataFrame(
    {
        "Data Type": df.dtypes,
        "Total Rows": len(df),
        "Null Rows": df.isnull().sum(),
        "Null Percentage": (df.isnull().sum() / len(df) * 100)
        .round(6)
        .apply(lambda x: f"{x}%"),
    }
)

info
# Out:
#                                Data Type  Total Rows  Null Rows  \
# cdparametresiseeaux               object         828          1
# cdparametre                      float64         828          8
# libmajparametre                   object         828          0
# libminparametre                   object         828          0
# casparam                          object         828         23
# categorie                         object         828          0
# sous catégorie                    object         828         28
# Détails sous catégorie            object         828        699
# Limite qualité                   float64         828         23
# Unité limite qualité              object         828         23
# Commentaire limite qualité        object         828        825
# Valeur sanitaire 1                object         828        657
# Unité valeur sanitaire 1          object         828        801
# Commentaire valeur sanitaire 1    object         828        788
# Valeur sanitaire 2               float64         828        827
# Unité valeur sanitaire 2          object         828        827
# Commentaire valeur sanitaire 2    object         828        827
#
#                                Null Percentage
# cdparametresiseeaux                  0.120773%
# cdparametre                          0.966184%
# libmajparametre                           0.0%
# libminparametre                           0.0%
# casparam                             2.777778%
# categorie                                 0.0%
# sous catégorie                       3.381643%
# Détails sous catégorie               84.42029%
# Limite qualité                       2.777778%
# Unité limite qualité                 2.777778%
# Commentaire limite qualité          99.637681%
# Valeur sanitaire 1                  79.347826%
# Unité valeur sanitaire 1             96.73913%
# Commentaire valeur sanitaire 1      95.169082%
# Valeur sanitaire 2                  99.879227%
# Unité valeur sanitaire 2            99.879227%
# Commentaire valeur sanitaire 2      99.879227%

# %%
# distinc category
unique_cat = df["categorie"].unique().tolist()
unique_cat
# Out:
# ['PFAS', 'CVM', 'Substances industrielles', 'pesticides']

# %%
unique_sous_cat = df["souscat"].dropna().unique().tolist()
unique_sous_cat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/open-source/13_pollution_eau_d4g/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'souscat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[160], line 1
# ----> 1 unique_sous_cat = df["souscat"].dropna().unique().tolist()
#       2 unique_sous_cat
#
# File ~/open-source/13_pollution_eau_d4g/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/open-source/13_pollution_eau_d4g/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'souscat'

# %%
# check uniqueness of cdparametresiseeaux and cdparametre
# found:cdparametre is more reliable than cdparametresiseeaux,
# because cdparametresiseeaux can be in reverse order:
# ex: cdparametre: 6381 =>cdparametresiseeaux: DIM2ESA or ESADIM2
# conclution: use cdparametre as key

# convert cdparametre field into int type instead of float
df["cdparametre"] = df["cdparametre"].fillna(0).astype(int)
c = df[df["cdparametre"].duplicated(keep=False)]
c.sort_values("cdparametre")[["cdparametresiseeaux", "cdparametre"]]
# Out:
#     cdparametresiseeaux  cdparametre
# 809                MFTC            0
# 64              CLTHSYN            0
# 63              CLTHAR6            0
# 150              TBZLM6            0
# 798                FPDF            0
# 794                 MDB            0
# 23                  NaN            0
# 796                ISOF            0
# 744                CNEB         1341
# 652               CLRNB         1341
# 223             DALAPON         2094
# 222             DAL_SPD         2094
# 618             IMAZAQU         2860
# 547             IMAZAQU         2860
# 721               PPCBS         5602
# 584               PPCBS         5602
# 54              DIM2ESA         6381
# 55              ESADIM2         6381
# 14                 PFOS         6561
# 15                 PFOS         6561
# 91               ESALCL         6800
# 92               LCLESA         6800
# 128              MTCOXA         6853
# 127              OXAMTC         6853
# 96               MTCESA         6854
# 95               ESAMTC         6854
# 89              CETCESA         6856
# 90              ESACETC         6856
# 122             CETCOXA         6862
# 123             OXACETC         6862
# 84              ESADMTH         6865
# 83              DMTHESA         6865
# 125             OXAMTZC         6894
# 126             MTZCOXA         6894
# 94              ESAMTZC         6895
# 93              MTZCESA         6895
# 686               DIMEP         7142
# 173             DIQDBMD         7142
# 65              CLTHALS         7717
# 68              CLTHALS         7717
# 53                 AUSN         7719
# 52                 AUSN         7719
# 57              DIM1ESA         7727
# 56              ESADIM1         7727
# 116              NOAMTC         7729
# 115              MTCNOA         7729
# 85              DMTHOXA         7735
# 86              OXADMTH         7735
# 66              471811R         8865
# 67              R471811         8865

# %%
# test Unité limite qualité, Unité valeur sanitaire1, Unité valeur sanitaire2
# conclution:
# 1) 13 rows has no Unite at all,
# 2) all parameters have µg/L as unity. verified manually the 13 no unity parameters.
columns_to_check = [
    "Unité limite qualité",
    "Unité valeur sanitaire 1",
    "Unité valeur sanitaire 2",
]
no_unity_value = df[df[columns_to_check].isnull().all(axis=1)]
no_unity_value[
    ["cdparametresiseeaux", "libmajparametre", "cdparametre"] + columns_to_check
]
# Out:
#    cdparametresiseeaux                       libmajparametre  cdparametre  \
# 6               PFDODA           ACIDE PERFLUORODODÉCANOIQUE         6507
# 7                 PFNA            ACIDE PERFLUORO-NONANOÏQUE         6508
# 8                 PFDA            ACIDE PERFLUORO-DECANOÏQUE         6509
# 9                PFUNA          ACIDE PERFLUORO UNDECANOÏQUE         6510
# 10               PFHPS     ACIDE PERFLUOROHEPTANE SULFONIQUE         6542
# 11              PFTRDA         ACIDE PERFLUORO TRIDECANOIQUE         6549
# 12                PFDS     ACIDE PERFLUORODECANE SULFONIQUE          6550
# 13              ASPFOS      ACIDE PERFLUOROOCTANE SULFONIQUE         6560
# 17                PFPS     ACIDE PERFLUOROPENTANE SULFONIQUE         8738
# 18                PFNS      ACIDE PERFLUORONONANE SULFONIQUE         8739
# 19              PFUNDS   ACIDE PERFLUORO UNDECANE SULFONIQUE         8740
# 20              PFDODS   ACIDE PERFLUORODODÉCANE SULFONIQUE          8741
# 21              PFTRDS  ACIDE PERFLUORO TRIDECANE SULFONIQUE         8742
#
#    Unité limite qualité Unité valeur sanitaire 1 Unité valeur sanitaire 2
# 6                   NaN                      NaN                      NaN
# 7                   NaN                      NaN                      NaN
# 8                   NaN                      NaN                      NaN
# 9                   NaN                      NaN                      NaN
# 10                  NaN                      NaN                      NaN
# 11                  NaN                      NaN                      NaN
# 12                  NaN                      NaN                      NaN
# 13                  NaN                      NaN                      NaN
# 17                  NaN                      NaN                      NaN
# 18                  NaN                      NaN                      NaN
# 19                  NaN                      NaN                      NaN
# 20                  NaN                      NaN                      NaN
# 21                  NaN                      NaN                      NaN

# %%
"""_summary_
clean, transform, and convert data to new csv file 
"""

# clean the raw data, and use the cleaned csv map_category_v2.csv as seed
# rename the columns as in edc_result
df.columns = df.columns.str.strip()
df = df.rename(
    columns={
        "sous catégorie": "souscat",
        "Détails sous catégorie": "detailsouscat",
        "Limite qualité": "limitequal",
        "Valeur sanitaire 1": "valsanitaire1",
        "Commentaire valeur sanitaire 1": "commentvalsanitaire1",
        "Valeur sanitaire 2": "valsanitaire2",
        "Commentaire valeur sanitaire 2": "commentvalsanitaire2",
    }
)
# add a new colum unite, all the unity we use here is µg/L
df["unite"] = (
    df["Unité limite qualité"]
    .combine_first(df["Unité valeur sanitaire 1"])
    .combine_first(df["Unité valeur sanitaire 2"])
)
# delete the null cdparametresiseeaux row
df = df[df["cdparametresiseeaux"].notna()]
# delete useless columns
colums_delete = [
    "Unité limite qualité",
    "Unité valeur sanitaire 1",
    "Unité valeur sanitaire 2",
    "Commentaire limite qualité",
]
df = df.drop(colums_delete, axis=1)
# new csv path
map_cat_path = Path.cwd().parent.parent / "dbt_/seeds/mapping_category_v2.csv"
# create a new file
df.to_csv(map_cat_path, index=False)

# %%
# show new colum and colum's type
df.dtypes
# Out:
# cdparametresiseeaux      object
# cdparametre             float64
# libmajparametre          object
# libminparametre          object
# casparam                 object
# categorie                object
# souscat                  object
# detailsouscat            object
# limitequal              float64
# valsanitaire1            object
# commentvalsanitaire1     object
# valsanitaire2           float64
# commentvalsanitaire2     object
# unite                    object
# dtype: object
